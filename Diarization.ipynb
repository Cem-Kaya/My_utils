# %%
import torch
from faster_whisper import WhisperModel
import whisperx
import os
import subprocess
import shlex
import unicodedata
import re
import shutil

print("CUDA:", torch.cuda.is_available())

# Configuration
supported_video_types = ["mp4", "webm", "mkv"]
supported_audio_types = ["mp3", "wav", "m4a", "opus"]
model_size = "large-v3"
device = "cuda"
batch_size = 48
compute_type = "float16"
YOUR_HF_TOKEN = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
ENABLE_VIDEO_CUTTING = False  # Set this to False to disable video cutting
MERGE_THRESHOLD = 1000  # Merge segments that are less than 1 second apart (1000 milliseconds)

max_speakers = 25
min_speakers = 12

# Initialize models
whisperx_model = whisperx.load_model(model_size, device, compute_type=compute_type)

# Function to convert a string to ASCII, replacing non-ASCII characters with underscore
def to_ascii(s):
    return re.sub(r'[^a-zA-Z0-9]', '_', unicodedata.normalize('NFKD', s).encode('ascii', 'ignore').decode('ascii'))

# Function to rename file to ASCII
def rename_file_to_ascii(file_path):
    dir_name, base_name = os.path.split(file_path)
    base_name_ascii = to_ascii(os.path.splitext(base_name)[0]) + os.path.splitext(base_name)[1]
    new_file_path = os.path.join(dir_name, base_name_ascii)
    os.rename(file_path, new_file_path)
    return new_file_path

# Function to merge close segments
def merge_segments(segments, threshold):
    if not segments:
        return []
    merged_segments = [segments[0]]
    for current in segments[1:]:
        previous = merged_segments[-1]
        if current[0] - previous[1] <= threshold:
            merged_segments[-1] = (previous[0], current[1])
        else:
            merged_segments.append(current)
    return merged_segments

# Function to extract speaker segments
def extract_speaker_segments(transcript, merge_threshold):
    speaker_segments = {}
    for entry in transcript:
        if 'speaker' not in entry:
            continue
        speaker = entry["speaker"]
        start = entry['start'] * 1000  # Convert to milliseconds
        end = entry['end'] * 1000      # Convert to milliseconds
        if speaker not in speaker_segments:
            speaker_segments[speaker] = []
        speaker_segments[speaker].append((start, end))
    
    for speaker in speaker_segments:
        speaker_segments[speaker] = merge_segments(speaker_segments[speaker], merge_threshold)
    
    return speaker_segments

# Function to create segment file
def create_segment_file(speaker_segments, media_path, output_dir, speaker):
    segment_file_content = ""
    for start, end in speaker_segments:
        segment_file_content += f"file '{media_path}'\ninpoint {start / 1000}\noutpoint {end / 1000}\n"

    segment_file_path = os.path.join(output_dir, f"{speaker}_segments.txt")
    with open(segment_file_path, "w") as segment_file:
        segment_file.write(segment_file_content)
    return segment_file_path

# Function to split media using FFmpeg with GPU acceleration
def split_media_ffmpeg(media_path, speaker_segments, output_dir, is_video):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    dir_name = os.path.basename(output_dir)
    media_type = "video" if is_video else "audio"
    for speaker, segments in speaker_segments.items():
        segment_file_path = create_segment_file(segments, media_path, output_dir, speaker)
        extension = ".mp4" if is_video else ".mp3"
        concatenated_output_path = os.path.join(output_dir, f"{speaker}_{dir_name}_combined{extension}")
        codec = "-c:v hevc_nvenc -preset fast" if is_video else "-c copy"
        concat_command = (
            f"ffmpeg -y -hwaccel cuda -f concat -safe 0 -i {shlex.quote(segment_file_path)} {codec} {shlex.quote(concatenated_output_path)}"
        )

        print(f"Running {media_type} split command: {concat_command}")
        result = subprocess.run(shlex.split(concat_command), capture_output=True, text=True)
        print(result.stdout)
        print(result.stderr)
        if result.returncode == 0:
            print(f"Exported combined {media_type} for {speaker} to {concatenated_output_path}")
        else:
            print(f"Failed to export combined {media_type} for {speaker}. FFmpeg error: {result.stderr}")

# Function to save speaker words to different files
def save_speaker_words(transcript, output_dir):
    speaker_words = {}
    for entry in transcript:
        speaker = entry.get("speaker", "unknown")
        text = entry.get("text", "")
        if speaker not in speaker_words:
            speaker_words[speaker] = []
        speaker_words[speaker].append(text)
    
    dir_name = os.path.basename(output_dir)
    for speaker, words in speaker_words.items():
        speaker_file = os.path.join(output_dir, f"{speaker}_{dir_name}_words.txt")
        with open(speaker_file, "w") as f:
            f.write(" ".join(words))
        print(f"Saved words for speaker {speaker} to {speaker_file}")

# Extract audio from video
def extract_audio_from_video(video_path, audio_output_path):
    command = f"ffmpeg -y -i {shlex.quote(video_path)} -vn -acodec libmp3lame {shlex.quote(audio_output_path)}"
    print(f"Running command: {command}")
    result = subprocess.run(shlex.split(command), capture_output=True, text=True)
    if result.returncode != 0:
        print(f"Failed to extract audio from video. FFmpeg error: {result.stderr}")
    else:
        print(f"Extracted audio to {audio_output_path}")

# Process all specified files in the current directory
files = [f for f in os.listdir('.') if f.split('.')[-1] in supported_video_types + supported_audio_types]
print("---FILES:", files)

for file in files:
    file_path = os.path.abspath(file)
    file_path_ascii = rename_file_to_ascii(file_path)
    output_dir = f"{os.path.splitext(file_path_ascii)[0]}_output"
    os.makedirs(output_dir, exist_ok=True)

    # Move the video file to the output directory
    new_media_path = os.path.join(output_dir, os.path.basename(file_path_ascii))
    shutil.move(file_path_ascii, new_media_path)

    if file.split('.')[-1] in supported_video_types:
        audio_path = os.path.join(output_dir, "extracted_audio.mp3")
        extract_audio_from_video(new_media_path, audio_path)
    else:
        audio_path = new_media_path

    # Transcription with WhisperX
    audio = whisperx.load_audio(audio_path)
    result = whisperx_model.transcribe(audio, batch_size=batch_size)
    dir_name = os.path.basename(output_dir)
    transcription_before_alignment_file = os.path.join(output_dir, f"1_transcription_before_alignment_{dir_name}.log")
    with open(transcription_before_alignment_file, "w") as f:
        f.write("Transcription before alignment:\n")
        for segment in result["segments"]:
            f.write(f"{segment}\n")

    model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
    result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
    transcription_after_alignment_file = os.path.join(output_dir, f"1_transcription_after_alignment_{dir_name}.log")
    with open(transcription_after_alignment_file, "w") as f:
        f.write("Transcription after alignment:\n")
        for segment in result["segments"]:
            f.write(f"{segment}\n")

    diarize_model = whisperx.DiarizationPipeline(use_auth_token=YOUR_HF_TOKEN, device=device, )
    diarize_segments = diarize_model(audio , min_speakers=min_speakers, max_speakers=max_speakers)
    diarization_file = os.path.join(output_dir, f"2_diarization_segments_{dir_name}.log")
    with open(diarization_file, "w") as f:
        f.write("Diarization segments:\n")
        for segment in diarize_segments:
            f.write(f"{segment}\n")

    result = whisperx.assign_word_speakers(diarize_segments, result)
    speaker_labels_file = os.path.join(output_dir, f"3_segments_with_speaker_ids_{dir_name}.log")
    with open(speaker_labels_file, "w") as f:
        for segment in result["segments"]:
            f.write(f"{segment}\n")

    speaker_segments = extract_speaker_segments(result["segments"], MERGE_THRESHOLD)
    
    if ENABLE_VIDEO_CUTTING and file.split('.')[-1] in supported_video_types:
        split_media_ffmpeg(new_media_path, speaker_segments, output_dir, is_video=True)
    else:
        split_media_ffmpeg(audio_path, speaker_segments, output_dir, is_video=False)
    
    save_speaker_words(result["segments"], output_dir)
# Out:
# CUDA: True
# Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.2.4. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint C:\Users\cemka\.cache\torch\whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.2.1. Bad things might happen unless you revert torch to 1.x.
# ---FILES: ['SPEAKER_02_42_output_combined.mp3', 'SPEAKER_07_13_output_combined.mp3']
# Detected language: en (1.00) in first 30s of audio...
# Running audio split command: ffmpeg -y -hwaccel cuda -f concat -safe 0 -i 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_10_segments.txt' -c copy 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_10_SPEAKER_02_42_output_combined_output_combined.mp3'
#
# ffmpeg version 7.0-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, concat, from 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_10_segments.txt':
#   Duration: 10:36:23.83, start: -0.009000, bitrate: 0 kb/s
#   Stream #0:0: Audio: mp3 (mp3float), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp3, to 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_10_SPEAKER_02_42_output_combined_output_combined.mp3':
#   Metadata:
#     TSSE            : Lavf61.1.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Press [q] to stop, [?] for help
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 18230558976 >= 18230446080
# size=   43008KiB time=00:45:55.54 bitrate= 127.9kbits/s speed=5.45e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 43820963424 >= 43820921088
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 50545444320 >= 50545260864
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 52355774016 >= 52355534112
# size=   59136KiB time=01:03:19.66 bitrate= 127.5kbits/s speed=3.71e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 53620533792 >= 53620364448
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 55535645088 >= 55535560416
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 57922633440 >= 57922619328
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 63441653184 >= 63441554400
# size=   70400KiB time=01:15:11.17 bitrate= 127.8kbits/s speed=2.93e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 64670258016 >= 64670201568
# size=   74240KiB time=01:19:26.12 bitrate= 127.6kbits/s speed=2.32e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 67259160864 >= 67259062080
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 71805666240 >= 71805482784
# size=   80384KiB time=01:25:47.58 bitrate= 127.9kbits/s speed=2e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 72642380832 >= 72642112704
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 78038089920 >= 78038019360
# size=   89856KiB time=01:36:03.76 bitrate= 127.7kbits/s speed=1.87e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 81337927104 >= 81337828320
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 81394727904 >= 81394544448
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 85171254336 >= 85171113216
# size=   96512KiB time=01:42:56.99 bitrate= 128.0kbits/s speed=1.72e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 87801773472 >= 87801773472
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 92160956160 >= 92160942048
# size=  102144KiB time=01:49:04.52 bitrate= 127.9kbits/s speed=1.59e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 92356026336 >= 92355899328
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 92656992960 >= 92656894176
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 94862938464 >= 94862755008
# size=  105728KiB time=01:52:46.41 bitrate= 128.0kbits/s speed=1.46e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 95487295680 >= 95487182784
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 96490376640 >= 96490179072
# size=  109312KiB time=01:56:38.24 bitrate= 128.0kbits/s speed=1.36e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 100328417280 >= 100328346720
# size=  112384KiB time=02:00:02.17 bitrate= 127.8kbits/s speed=1.27e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 101636754912 >= 101636726688
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 105769101312 >= 105769044864
# size=  119296KiB time=02:07:24.85 bitrate= 127.8kbits/s speed=1.24e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 111433700448 >= 111433488768
# size=  129536KiB time=02:18:15.07 bitrate= 127.9kbits/s speed=1.24e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 117059773824 >= 117059646816
# size=  143616KiB time=02:33:20.29 bitrate= 127.9kbits/s speed=1.27e+03x
# size=  154624KiB time=02:45:05.07 bitrate= 127.9kbits/s speed=1.28e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 146233497312 >= 146233469088
# size=  164096KiB time=02:55:15.03 bitrate= 127.8kbits/s speed=1.28e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 148387863456 >= 148387863456
# size=  172288KiB time=03:03:45.40 bitrate= 128.0kbits/s speed=1.26e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 155590204896 >= 155590190784
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 157183717824 >= 157183604928
# size=  174592KiB time=03:06:21.01 bitrate= 127.9kbits/s speed=1.21e+03x
# size=  184576KiB time=03:16:56.68 bitrate= 128.0kbits/s speed=1.21e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 166756762368 >= 166756508352
# size=  191232KiB time=03:24:04.49 bitrate= 127.9kbits/s speed=1.19e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 172794017088 >= 172793988864
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 173203123968 >= 173202884064
# size=  192512KiB time=03:25:21.08 bitrate= 128.0kbits/s speed=1.14e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 173874841056 >= 173874714048
# size=  193792KiB time=03:26:46.32 bitrate= 128.0kbits/s speed=1.09e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 175077762048 >= 175077762048
# size=  196608KiB time=03:29:54.83 bitrate= 127.9kbits/s speed=1.06e+03x
# size=  199680KiB time=03:33:06.52 bitrate= 127.9kbits/s speed=1.03e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 180443102112 >= 180443003328
# size=  208896KiB time=03:43:02.56 bitrate= 127.9kbits/s speed=1.04e+03x
# size=  211968KiB time=03:46:10.42 bitrate= 128.0kbits/s speed=1.01e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 192022717824 >= 192022703712
# size=  214016KiB time=03:48:26.91 bitrate= 127.9kbits/s speed= 984x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 193431645792 >= 193431603456
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 197700088320 >= 197700074208
# size=  228608KiB time=04:03:54.94 bitrate= 128.0kbits/s speed=1.01e+03x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 206527976928 >= 206527976928
# size=  230912KiB time=04:06:26.23 bitrate= 127.9kbits/s speed= 989x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 208663066080 >= 208662981408
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 209713930272 >= 209713803264
# size=  234240KiB time=04:09:50.12 bitrate= 128.0kbits/s speed= 969x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 211540347648 >= 211540093632
# size=  235008KiB time=04:10:40.55 bitrate= 128.0kbits/s speed= 941x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 212252015808 >= 212251945248
# size=  238336KiB time=04:14:14.58 bitrate= 128.0kbits/s speed= 924x
# size=  256000KiB time=04:33:12.12 bitrate= 127.9kbits/s speed= 963x
# size=  259840KiB time=04:37:13.72 bitrate= 128.0kbits/s speed= 948x
# size=  261120KiB time=04:38:41.10 bitrate= 127.9kbits/s speed= 926x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 235967951520 >= 235967768064
# size=  263936KiB time=04:41:36.14 bitrate= 128.0kbits/s speed= 910x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 241270817760 >= 241270761312
# size=  267776KiB time=04:45:45.76 bitrate= 127.9kbits/s speed= 898x
# size=  277248KiB time=04:55:46.76 bitrate= 128.0kbits/s speed= 905x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 251267659776 >= 251267659776
# size=  278784KiB time=04:57:35.76 bitrate= 127.9kbits/s speed= 888x
# size=  280832KiB time=04:59:45.86 bitrate= 127.9kbits/s speed= 872x
# size=  283392KiB time=05:02:18.08 bitrate= 128.0kbits/s speed= 858x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 255964316832 >= 255964175712
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 259243691616 >= 259243578720
# size=  288512KiB time=05:07:45.33 bitrate= 128.0kbits/s speed= 852x
# size=  289024KiB time=05:08:21.77 bitrate= 128.0kbits/s speed= 834x
# size=  289024KiB time=05:08:27.87 bitrate= 127.9kbits/s speed= 815x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 261182821536 >= 261182680416
# size=  297984KiB time=05:18:02.28 bitrate= 127.9kbits/s speed= 822x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 269288881344 >= 269288867232
# size=  307456KiB time=05:28:03.12 bitrate= 128.0kbits/s speed= 829x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 277767921312 >= 277767878976
# size=  308480KiB time=05:29:06.43 bitrate= 128.0kbits/s speed= 814x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 278661337920 >= 278661281472
# size=  314112KiB time=05:35:07.94 bitrate= 128.0kbits/s speed= 812x
# size=  317440KiB time=05:38:38.40 bitrate= 128.0kbits/s speed= 804x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 286733049120 >= 286732978560
# size=  317696KiB time=05:39:00.01 bitrate= 128.0kbits/s speed= 789x
# size=  317952KiB time=05:39:08.51 bitrate= 128.0kbits/s speed= 773x
# size=  319232KiB time=05:40:32.97 bitrate= 128.0kbits/s speed= 762x
# size=  321536KiB time=05:43:04.46 bitrate= 128.0kbits/s speed= 753x
# size=  332288KiB time=05:54:27.81 bitrate= 128.0kbits/s speed= 763x
# size=  336128KiB time=05:58:29.84 bitrate= 128.0kbits/s speed= 758x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 303546551616 >= 303546481056
# size=  336640KiB time=05:59:08.93 bitrate= 128.0kbits/s speed= 746x
# size=  342272KiB time=06:05:05.17 bitrate= 128.0kbits/s speed= 745x
# size=  342528KiB time=06:05:20.15 bitrate= 128.0kbits/s speed= 733x
# size=  346368KiB time=06:09:29.63 bitrate= 128.0kbits/s speed= 728x
# size=  352000KiB time=06:15:37.29 bitrate= 127.9kbits/s speed= 728x
# size=  354816KiB time=06:18:29.66 bitrate= 128.0kbits/s speed= 722x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 320478496128 >= 320478369120
# size=  354816KiB time=06:18:41.63 bitrate= 127.9kbits/s speed= 710x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 320647374432 >= 320647360320
# size=  355072KiB time=06:18:43.17 bitrate= 128.0kbits/s speed= 699x
# size=  356096KiB time=06:20:02.15 bitrate= 127.9kbits/s speed= 690x
# size=  356352KiB time=06:20:16.04 bitrate= 127.9kbits/s speed= 680x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 321979744800 >= 321979674240
# size=  356608KiB time=06:20:23.74 bitrate= 128.0kbits/s speed= 670x
# size=  357376KiB time=06:21:15.48 bitrate= 128.0kbits/s speed= 662x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 322818519744 >= 322818449184
# size=  358400KiB time=06:22:16.94 bitrate= 128.0kbits/s speed= 654x
# size=  359680KiB time=06:23:38.12 bitrate= 128.0kbits/s speed= 646x
# size=  360192KiB time=06:24:13.64 bitrate= 128.0kbits/s speed= 638x
# size=  360192KiB time=06:24:18.45 bitrate= 128.0kbits/s speed= 629x
# size=  360448KiB time=06:24:27.85 bitrate= 128.0kbits/s speed= 621x
# size=  360704KiB time=06:24:55.89 bitrate= 127.9kbits/s speed= 613x
# size=  362496KiB time=06:26:37.08 bitrate= 128.0kbits/s speed= 607x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 327356854272 >= 327356755488
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 327768600096 >= 327768600096
# size=  363264KiB time=06:27:35.70 bitrate= 128.0kbits/s speed= 601x
# size=  363520KiB time=06:27:57.43 bitrate= 127.9kbits/s speed= 594x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 328490809920 >= 328490781696
# size=  364288KiB time=06:28:37.29 bitrate= 128.0kbits/s speed= 587x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 329053342464 >= 329053144896
# size=  364800KiB time=06:29:16.59 bitrate= 127.9kbits/s speed= 580x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 329607915840 >= 329607873504
# size=  367360KiB time=06:31:56.43 bitrate= 128.0kbits/s speed= 577x
# size=  368384KiB time=06:33:06.97 bitrate= 127.9kbits/s speed= 572x
# size=  368640KiB time=06:33:14.80 bitrate= 128.0kbits/s speed= 565x
# size=  368640KiB time=06:33:25.70 bitrate= 127.9kbits/s speed= 558x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 333123342048 >= 333123257376
# size=  369152KiB time=06:33:46.60 bitrate= 128.0kbits/s speed= 552x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 333418254624 >= 333418141728
# size=  369408KiB time=06:34:11.43 bitrate= 127.9kbits/s speed= 546x
# size=  369920KiB time=06:34:32.93 bitrate= 128.0kbits/s speed= 540x
# size=  369920KiB time=06:34:46.59 bitrate= 127.9kbits/s speed= 534x
# size=  371456KiB time=06:36:20.85 bitrate= 128.0kbits/s speed= 530x
# size=  371712KiB time=06:36:28.19 bitrate= 128.0kbits/s speed= 524x
# size=  371968KiB time=06:36:53.50 bitrate= 128.0kbits/s speed= 519x
# size=  372224KiB time=06:37:03.06 bitrate= 128.0kbits/s speed= 513x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 336190712256 >= 336190684032
# size=  376576KiB time=06:41:43.11 bitrate= 128.0kbits/s speed= 513x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 340142834304 >= 340142834304
# size=  376832KiB time=06:42:04.33 bitrate= 128.0kbits/s speed= 508x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 340442234496 >= 340442220384
# size=  396288KiB time=07:02:44.96 bitrate= 128.0kbits/s speed= 529x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 359179117920 >= 359179103808
# size=  398336KiB time=07:04:59.17 bitrate= 128.0kbits/s speed= 526x
# size=  406784KiB time=07:13:52.49 bitrate= 128.0kbits/s speed= 531x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 367370273088 >= 367370160192
# size=  407552KiB time=07:14:40.87 bitrate= 128.0kbits/s speed= 527x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 368052955200 >= 368052842304
# size=  409856KiB time=07:17:20.70 bitrate= 128.0kbits/s speed= 524x
# size=  410368KiB time=07:17:49.20 bitrate= 128.0kbits/s speed= 520x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 370710654048 >= 370710583488
# size=  411392KiB time=07:18:54.07 bitrate= 128.0kbits/s speed= 516x
# size=  412416KiB time=07:19:56.15 bitrate= 128.0kbits/s speed= 512x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 372502172448 >= 372502158336
# size=  414720KiB time=07:22:29.70 bitrate= 128.0kbits/s speed= 509x
# size=  414720KiB time=07:22:34.44 bitrate= 127.9kbits/s speed= 505x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 374735975040 >= 374735918592
# size=  415744KiB time=07:23:29.25 bitrate= 128.0kbits/s speed= 501x
# size=  415744KiB time=07:23:39.97 bitrate= 127.9kbits/s speed= 496x
# size=  416000KiB time=07:23:43.77 bitrate= 128.0kbits/s speed= 491x
# size=  418816KiB time=07:26:42.24 bitrate= 128.0kbits/s speed= 490x
# size=  418816KiB time=07:26:44.39 bitrate= 128.0kbits/s speed= 486x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 378263241216 >= 378263227104
# size=  419584KiB time=07:27:43.33 bitrate= 128.0kbits/s speed= 482x
# size=  420608KiB time=07:28:49.34 bitrate= 128.0kbits/s speed= 479x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 380026535616 >= 380026408608
# size=  423168KiB time=07:31:30.20 bitrate= 128.0kbits/s speed= 477x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 382296634272 >= 382296493152
# size=  423168KiB time=07:31:31.51 bitrate= 128.0kbits/s speed= 473x
# size=  423680KiB time=07:32:00.52 bitrate= 128.0kbits/s speed= 469x
# size=  424704KiB time=07:33:02.28 bitrate= 128.0kbits/s speed= 466x
# size=  429056KiB time=07:37:41.38 bitrate= 128.0kbits/s speed= 467x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 387534712320 >= 387534698208
# size=  429824KiB time=07:38:40.87 bitrate= 127.9kbits/s speed= 464x
# size=  431872KiB time=07:40:47.46 bitrate= 128.0kbits/s speed= 462x
# size=  431872KiB time=07:40:50.81 bitrate= 127.9kbits/s speed= 458x
# size=  434944KiB time=07:44:05.95 bitrate= 128.0kbits/s speed= 457x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 392961806496 >= 392961778272
# size=  435712KiB time=07:44:44.45 bitrate= 128.0kbits/s speed= 454x
# size=  435712KiB time=07:44:44.45 bitrate= 128.0kbits/s speed= 450x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 393505033824 >= 393504878592
# size=  438528KiB time=07:47:45.68 bitrate= 128.0kbits/s speed= 450x
# size=  440576KiB time=07:49:52.94 bitrate= 128.0kbits/s speed= 448x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 397858501152 >= 397858487040
# size=  441344KiB time=07:50:53.28 bitrate= 128.0kbits/s speed= 445x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 398709948672 >= 398709920448
# size=  441856KiB time=07:51:17.11 bitrate= 128.0kbits/s speed= 442x
# size=  443392KiB time=07:53:09.02 bitrate= 127.9kbits/s speed= 440x
# size=  444160KiB time=07:53:48.56 bitrate= 128.0kbits/s speed= 437x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 401183542368 >= 401183358912
# size=  444160KiB time=07:53:50.30 bitrate= 128.0kbits/s speed= 434x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 401208083136 >= 401208012576
# size=  445440KiB time=07:55:12.92 bitrate= 128.0kbits/s speed= 432x
# size=  448256KiB time=07:58:17.19 bitrate= 128.0kbits/s speed= 431x
# size=  448768KiB time=07:58:49.72 bitrate= 128.0kbits/s speed= 428x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 405433498176 >= 405433300608
# size=  451072KiB time=08:01:04.68 bitrate= 128.0kbits/s speed= 427x
# size=  459520KiB time=08:10:17.71 bitrate= 128.0kbits/s speed= 432x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 415142469504 >= 415142413056
# size=  460288KiB time=08:11:05.64 bitrate= 128.0kbits/s speed= 429x
# size=  462848KiB time=08:13:52.61 bitrate= 128.0kbits/s speed= 429x
# size=  469248KiB time=08:20:40.13 bitrate= 128.0kbits/s speed= 431x
# size=  477696KiB time=08:29:35.88 bitrate= 128.0kbits/s speed= 436x
# size=  488192KiB time=08:40:51.45 bitrate= 128.0kbits/s speed= 442x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 441020222496 >= 441020151936
# size=  493568KiB time=08:46:31.94 bitrate= 128.0kbits/s speed= 444x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 445825118592 >= 445824864576
# size=  495616KiB time=08:48:47.52 bitrate= 128.0kbits/s speed= 442x
# size=  498688KiB time=08:51:57.60 bitrate= 128.0kbits/s speed= 442x
# size=  498688KiB time=08:51:57.60 bitrate= 128.0kbits/s speed= 439x
# size=  499456KiB time=08:52:42.65 bitrate= 128.0kbits/s speed= 436x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 451056691008 >= 451056465216
# size=  512000KiB time=09:06:10.69 bitrate= 128.0kbits/s speed= 444x
# size=  515584KiB time=09:10:06.63 bitrate= 128.0kbits/s speed= 444x
# size=  521216KiB time=09:15:58.78 bitrate= 128.0kbits/s speed= 446x
# size=  525312KiB time=09:20:18.88 bitrate= 128.0kbits/s speed= 446x
# size=  539392KiB time=09:35:23.36 bitrate= 128.0kbits/s speed= 455x
# size=  544000KiB time=09:40:25.83 bitrate= 128.0kbits/s speed= 456x
# size=  547328KiB time=09:43:57.25 bitrate= 128.0kbits/s speed= 456x
# size=  547584KiB time=09:44:08.03 bitrate= 128.0kbits/s speed= 453x
# size=  547584KiB time=09:44:08.03 bitrate= 128.0kbits/s speed= 450x
# size=  556288KiB time=09:53:21.73 bitrate= 128.0kbits/s speed= 454x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 502411359744 >= 502411345632
# size=  558336KiB time=09:55:34.50 bitrate= 128.0kbits/s speed= 453x
# size=  558336KiB time=09:55:34.50 bitrate= 128.0kbits/s speed= 450x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 504284967648 >= 504284939424
# size=  566016KiB time=10:03:41.31 bitrate= 128.0kbits/s speed= 453x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 511154886816 >= 511154759808
# size=  570368KiB time=10:08:25.80 bitrate= 128.0kbits/s speed= 453x
# size=  570368KiB time=10:08:25.80 bitrate= 128.0kbits/s speed= 451x
# size=  570624KiB time=10:08:44.00 bitrate= 128.0kbits/s speed= 448x
# size=  572416KiB time=10:10:39.85 bitrate= 128.0kbits/s speed= 447x
# size=  572416KiB time=10:10:39.85 bitrate= 128.0kbits/s speed= 444x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 517061280960 >= 517061168064
# size=  572672KiB time=10:11:01.44 bitrate= 128.0kbits/s speed= 441x
# size=  572928KiB time=10:11:13.22 bitrate= 128.0kbits/s speed= 439x
# size=  572928KiB time=10:11:13.22 bitrate= 128.0kbits/s speed= 436x
# size=  573184KiB time=10:11:27.26 bitrate= 128.0kbits/s speed= 434x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 517730359104 >= 517730344992
# size=  577024KiB time=10:15:27.24 bitrate= 128.0kbits/s speed= 434x
# size=  577024KiB time=10:15:27.24 bitrate= 128.0kbits/s speed= 431x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 521116886304 >= 521116815744
# size=  583680KiB time=10:22:41.49 bitrate= 128.0kbits/s speed= 434x
# [mp3 @ 0000019476954340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 527245036416 >= 527245022304
# size=  588544KiB time=10:27:58.17 bitrate= 128.0kbits/s speed= 435x
# size=  588544KiB time=10:27:58.17 bitrate= 128.0kbits/s speed= 432x
# size=  589312KiB time=10:28:40.98 bitrate= 128.0kbits/s speed= 430x
# size=  594432KiB time=10:34:00.05 bitrate= 128.0kbits/s speed= 431x
# size=  594432KiB time=10:34:00.05 bitrate= 128.0kbits/s speed= 429x
# [out#0/mp3 @ 0000019476938540] video:0KiB audio:596698KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.000070%
# size=  596699KiB time=10:36:23.84 bitrate= 128.0kbits/s speed= 429x
#
# Exported combined audio for SPEAKER_10 to z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_10_SPEAKER_02_42_output_combined_output_combined.mp3
# Running audio split command: ffmpeg -y -hwaccel cuda -f concat -safe 0 -i 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_00_segments.txt' -c copy 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_00_SPEAKER_02_42_output_combined_output_combined.mp3'
#
# ffmpeg version 7.0-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, concat, from 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_00_segments.txt':
#   Duration: 00:02:02.04, start: -0.013000, bitrate: 0 kb/s
#   Stream #0:0: Audio: mp3 (mp3float), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp3, to 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_00_SPEAKER_02_42_output_combined_output_combined.mp3':
#   Metadata:
#     TSSE            : Lavf61.1.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Press [q] to stop, [?] for help
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 4064256 >= 3909024
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 326565792 >= 326551680
# size=     512KiB time=00:00:35.33 bitrate= 118.7kbits/s speed=67.4x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 807615648 >= 807389856
# size=     768KiB time=00:01:03.91 bitrate=  98.4kbits/s speed=62.2x
# size=    1024KiB time=00:01:12.08 bitrate= 116.4kbits/s speed=46.7x
# size=    1024KiB time=00:01:12.73 bitrate= 115.3kbits/s speed=35.3x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1026027072 >= 1025998848
# size=    1024KiB time=00:01:12.84 bitrate= 115.2kbits/s speed=28.3x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1029611520 >= 1029583296
# size=    1024KiB time=00:01:13.77 bitrate= 113.7kbits/s speed=23.8x
# size=    1024KiB time=00:01:21.45 bitrate= 103.0kbits/s speed=22.5x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1149182496 >= 1149126048
# size=    1280KiB time=00:01:22.02 bitrate= 127.8kbits/s speed=19.9x
# size=    1280KiB time=00:01:31.49 bitrate= 114.6kbits/s speed=19.7x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1290782304 >= 1290711744
# size=    1280KiB time=00:01:31.99 bitrate= 114.0kbits/s speed=17.9x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1297824192 >= 1297753632
# size=    1280KiB time=00:01:35.58 bitrate= 109.7kbits/s speed=16.9x
# size=    1280KiB time=00:01:36.44 bitrate= 108.7kbits/s speed=15.6x
# size=    1280KiB time=00:01:36.63 bitrate= 108.5kbits/s speed=14.4x
# size=    1536KiB time=00:01:38.48 bitrate= 127.8kbits/s speed=13.7x
# size=    1536KiB time=00:01:41.50 bitrate= 124.0kbits/s speed=13.1x
# size=    1536KiB time=00:01:42.29 bitrate= 123.0kbits/s speed=12.4x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1443262464 >= 1443121344
# size=    1536KiB time=00:01:43.46 bitrate= 121.6kbits/s speed=11.8x
# size=    1536KiB time=00:01:43.46 bitrate= 121.6kbits/s speed=11.2x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1459717056 >= 1459702944
# size=    1536KiB time=00:01:43.60 bitrate= 121.5kbits/s speed=10.6x
# size=    1536KiB time=00:01:44.12 bitrate= 120.8kbits/s speed=10.1x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1469115648 >= 1469073312
# size=    1536KiB time=00:01:45.97 bitrate= 118.7kbits/s speed=9.78x
# size=    1536KiB time=00:01:47.00 bitrate= 117.6kbits/s speed=9.44x
# size=    1536KiB time=00:01:47.00 bitrate= 117.6kbits/s speed=9.02x
# size=    1536KiB time=00:01:47.79 bitrate= 116.7kbits/s speed=8.71x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1520864352 >= 1520822016
# size=    1536KiB time=00:01:51.94 bitrate= 112.4kbits/s speed=8.68x
# size=    1536KiB time=00:01:51.94 bitrate= 112.4kbits/s speed=8.35x
# [mp3 @ 00000269c8f54a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1579415040 >= 1579231584
# [out#0/mp3 @ 00000269c8f7edc0] video:0KiB audio:1917KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.021799%
# size=    1918KiB time=00:02:02.05 bitrate= 128.7kbits/s speed=9.07x
#
# Exported combined audio for SPEAKER_00 to z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_00_SPEAKER_02_42_output_combined_output_combined.mp3
# Running audio split command: ffmpeg -y -hwaccel cuda -f concat -safe 0 -i 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_05_segments.txt' -c copy 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_05_SPEAKER_02_42_output_combined_output_combined.mp3'
#
# ffmpeg version 7.0-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, concat, from 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_05_segments.txt':
#   Duration: 00:04:49.01, start: -0.009000, bitrate: 0 kb/s
#   Stream #0:0: Audio: mp3 (mp3float), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp3, to 'z:\AI\Whisper\SPEAKER_02_42_output_combined_output\SPEAKER_05_SPEAKER_02_42_output_combined_output_combined.mp3':
#   Metadata:
#     TSSE            : Lavf61.1.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Press [q] to stop, [?] for help
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 86831136 >= 86831136
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 181706112 >= 181522656
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 187619040 >= 187407360
# size=     256KiB time=00:00:28.93 bitrate=  72.5kbits/s speed=  55x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 408048480 >= 407949696
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 704626272 >= 704499264
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 909744192 >= 909715968
# size=    1280KiB time=00:01:21.62 bitrate= 128.5kbits/s speed=78.2x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1151539200 >= 1151510976
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1308323520 >= 1308224736
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1339045344 >= 1338946560
# size=    1536KiB time=00:01:48.39 bitrate= 116.1kbits/s speed=70.1x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1541651328 >= 1541510208
# size=    1536KiB time=00:01:50.62 bitrate= 113.7kbits/s speed=53.5x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1560843648 >= 1560744864
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1848629664 >= 1848432096
# size=    2048KiB time=00:02:18.84 bitrate= 120.8kbits/s speed=53.8x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1958971392 >= 1958957280
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1960650720 >= 1960566048
# size=    2048KiB time=00:02:19.31 bitrate= 120.4kbits/s speed=44.9x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2000361888 >= 2000291328
# size=    2048KiB time=00:02:22.70 bitrate= 117.6kbits/s speed=39.4x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2013500160 >= 2013429600
# size=    2304KiB time=00:02:38.77 bitrate= 118.9kbits/s speed=38.4x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2240251776 >= 2240181216
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2245261536 >= 2245247424
# size=    2304KiB time=00:02:41.57 bitrate= 116.8kbits/s speed=34.7x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2452411584 >= 2452270464
# size=    2816KiB time=00:02:59.72 bitrate= 128.4kbits/s speed=34.8x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2569174272 >= 2569103712
# size=    2816KiB time=00:03:06.75 bitrate= 123.5kbits/s speed=32.9x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2635147872 >= 2634950304
# size=    2816KiB time=00:03:12.12 bitrate= 120.1kbits/s speed=  31x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2710971648 >= 2710872864
# size=    2816KiB time=00:03:13.75 bitrate= 119.1kbits/s speed=28.9x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2743542144 >= 2743415136
# size=    2816KiB time=00:03:15.33 bitrate= 118.1kbits/s speed=  27x
# size=    2816KiB time=00:03:15.47 bitrate= 118.0kbits/s speed=25.2x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2758204512 >= 2757936384
# size=    3072KiB time=00:03:16.15 bitrate= 128.3kbits/s speed=23.7x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2767758336 >= 2767560768
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 2828185920 >= 2828087136
# size=    3072KiB time=00:03:30.60 bitrate= 119.5kbits/s speed=  24x
# size=    3328KiB time=00:03:33.27 bitrate= 127.8kbits/s speed=  23x
# size=    3328KiB time=00:03:41.87 bitrate= 122.9kbits/s speed=22.6x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3130690752 >= 3130436736
# size=    3328KiB time=00:03:43.86 bitrate= 121.8kbits/s speed=21.7x
# size=    3328KiB time=00:03:44.45 bitrate= 121.5kbits/s speed=20.7x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3167113824 >= 3167000928
# size=    3328KiB time=00:03:44.94 bitrate= 121.2kbits/s speed=19.8x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3174113376 >= 3174000480
# size=    3840KiB time=00:04:06.53 bitrate= 127.6kbits/s speed=20.8x
# size=    3840KiB time=00:04:06.53 bitrate= 127.6kbits/s speed=19.9x
# size=    3840KiB time=00:04:07.10 bitrate= 127.3kbits/s speed=19.2x
# size=    3840KiB time=00:04:08.12 bitrate= 126.8kbits/s speed=18.5x
# size=    3840KiB time=00:04:14.38 bitrate= 123.7kbits/s speed=18.3x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3589500096 >= 3589316640
# size=    4096KiB time=00:04:21.47 bitrate= 128.3kbits/s speed=18.1x
# size=    4096KiB time=00:04:25.20 bitrate= 126.5kbits/s speed=17.7x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3742262496 >= 3742191936
# size=    4096KiB time=00:04:25.80 bitrate= 126.2kbits/s speed=17.2x
# size=    4096KiB time=00:04:31.42 bitrate= 123.6kbits/s speed=  17x
# size=    4096KiB time=00:04:31.42 bitrate= 123.6kbits/s speed=16.4x
# size=    4096KiB time=00:04:32.21 bitrate= 123.3kbits/s speed=  16x
# size=    4096KiB time=00:04:32.41 bitrate= 123.2kbits/s speed=15.5x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3844010016 >= 3843868896
# size=    4096KiB time=00:04:33.19 bitrate= 122.8kbits/s speed=15.1x
# size=    4096KiB time=00:04:33.19 bitrate= 122.8kbits/s speed=14.7x
# size=    4096KiB time=00:04:33.56 bitrate= 122.7kbits/s speed=14.3x
# size=    4096KiB time=00:04:33.80 bitrate= 122.5kbits/s speed=  14x
# [mp3 @ 0000020877c51e40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 3863639808 >= 3863597472
# size=    4096KiB time=00:04:35.43 bitrate= 121.8kbits/s speed=13.7x
# size=    4096KiB time=00:04:35.43 bitrate= 121.8kbits/s speed=13.4x
# size=    4352KiB time=00:04:44.46 bitrate= 125.3kbits/s speed=13.5x
# size=    4352KiB time=00:04:44.98 bitrate= 125.1kbits/s speed=13.2x
# size=    4352KiB time=00:04:44.98 bitrate= 125.1kbits/s speed=12.9x
# size=    4352KiB time=00:04:47.18 bitrate= 124.1kbits/s speed=12.7x
# ...
# size=      81KiB time=00:00:04.90 bitrate= 136.0kbits/s speed= 1.9x
# size=      88KiB time=00:00:05.31 bitrate= 136.0kbits/s speed=1.72x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 74596032 >= 74596032
# size=      91KiB time=00:00:05.47 bitrate= 136.3kbits/s speed=1.52x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 76966848 >= 76783392
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 80508960 >= 80452512
# size=     110KiB time=00:00:06.63 bitrate= 136.1kbits/s speed=1.61x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 93322656 >= 93252096
# size=     117KiB time=00:00:07.01 bitrate= 136.2kbits/s speed=1.51x
# size=     120KiB time=00:00:07.18 bitrate= 136.4kbits/s speed=1.39x
# size=     125KiB time=00:00:07.50 bitrate= 136.3kbits/s speed=1.32x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 105600096 >= 105374304
# size=     129KiB time=00:00:07.70 bitrate= 136.8kbits/s speed=1.24x
# size=     131KiB time=00:00:07.85 bitrate= 136.9kbits/s speed=1.17x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 110567520 >= 110567520
# size=     135KiB time=00:00:08.07 bitrate= 137.0kbits/s speed=1.12x
# size=     139KiB time=00:00:08.29 bitrate= 137.0kbits/s speed=1.07x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 116762688 >= 116607456
# size=     143KiB time=00:00:08.52 bitrate= 137.3kbits/s speed=1.03x
# size=     143KiB time=00:00:08.52 bitrate= 137.3kbits/s speed=0.971x
# [mp3 @ 000002cef92d5340] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 119994336 >= 119966112
# size=     146KiB time=00:00:08.71 bitrate= 137.5kbits/s speed=0.939x
# [out#0/mp3 @ 000002cef92c1580] video:0KiB audio:150KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.279344%
# size=     150KiB time=00:00:08.92 bitrate= 137.8kbits/s speed=0.936x
#
# Exported combined audio for SPEAKER_01 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_01_SPEAKER_07_13_output_combined_output_combined.mp3
# Running audio split command: ffmpeg -y -hwaccel cuda -f concat -safe 0 -i 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_segments.txt' -c copy 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_SPEAKER_07_13_output_combined_output_combined.mp3'
#
# ffmpeg version 7.0-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, concat, from 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_segments.txt':
#   Duration: 00:01:39.64, start: -0.015000, bitrate: 0 kb/s
#   Stream #0:0: Audio: mp3 (mp3float), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp3, to 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_SPEAKER_07_13_output_combined_output_combined.mp3':
#   Metadata:
#     TSSE            : Lavf61.1.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Press [q] to stop, [?] for help
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 6110496 >= 5870592
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 106460928 >= 106418592
# size=     256KiB time=00:00:19.68 bitrate= 106.6kbits/s speed=  39x
# size=     512KiB time=00:00:45.26 bitrate=  92.7kbits/s speed=44.3x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 638440992 >= 638412768
# size=     512KiB time=00:00:47.81 bitrate=  87.7kbits/s speed=31.1x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 674468928 >= 674454816
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 676486944 >= 676345824
# size=     512KiB time=00:00:48.35 bitrate=  86.7kbits/s speed=23.5x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 682103520 >= 682032960
# size=     768KiB time=00:00:49.02 bitrate= 128.3kbits/s speed=  19x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 700491456 >= 700378560
# size=     768KiB time=00:00:50.01 bitrate= 125.8kbits/s speed=16.2x
# size=     768KiB time=00:00:51.39 bitrate= 122.4kbits/s speed=14.2x
# size=     768KiB time=00:00:54.60 bitrate= 115.2kbits/s speed=13.2x
# size=     768KiB time=00:00:58.58 bitrate= 107.4kbits/s speed=12.6x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 826426944 >= 826271712
# size=     768KiB time=00:01:03.95 bitrate=  98.4kbits/s speed=12.4x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 902137824 >= 902010816
# size=     768KiB time=00:01:04.15 bitrate=  98.1kbits/s speed=11.3x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 905059008 >= 905016672
# size=    1024KiB time=00:01:05.85 bitrate= 127.4kbits/s speed=10.6x
# size=    1024KiB time=00:01:06.05 bitrate= 127.0kbits/s speed=9.84x
# size=    1024KiB time=00:01:06.54 bitrate= 126.1kbits/s speed=9.21x
# size=    1024KiB time=00:01:07.04 bitrate= 125.1kbits/s speed=8.66x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 945758016 >= 945489888
# size=    1024KiB time=00:01:07.21 bitrate= 124.8kbits/s speed=8.13x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 948199392 >= 948185280
# size=    1024KiB time=00:01:16.74 bitrate= 109.3kbits/s speed=8.75x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1082644416 >= 1082559744
# size=    1024KiB time=00:01:17.19 bitrate= 108.7kbits/s speed=8.31x
# size=    1024KiB time=00:01:17.19 bitrate= 108.7kbits/s speed=7.87x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1088994816 >= 1088726688
# size=    1024KiB time=00:01:17.48 bitrate= 108.3kbits/s speed= 7.5x
# size=    1024KiB time=00:01:17.75 bitrate= 107.9kbits/s speed=7.18x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1096883424 >= 1096883424
# size=    1024KiB time=00:01:18.23 bitrate= 107.2kbits/s speed=6.89x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1103657184 >= 1103487840
# size=    1024KiB time=00:01:19.03 bitrate= 106.1kbits/s speed=6.66x
# size=    1024KiB time=00:01:19.45 bitrate= 105.6kbits/s speed=6.41x
# size=    1024KiB time=00:01:19.45 bitrate= 105.6kbits/s speed=6.16x
# size=    1280KiB time=00:01:26.81 bitrate= 120.8kbits/s speed=6.47x
# size=    1280KiB time=00:01:37.01 bitrate= 108.1kbits/s speed=6.97x
# size=    1280KiB time=00:01:37.21 bitrate= 107.9kbits/s speed=6.73x
# size=    1536KiB time=00:01:38.04 bitrate= 128.3kbits/s speed=6.55x
# size=    1536KiB time=00:01:38.04 bitrate= 128.3kbits/s speed=6.33x
# [mp3 @ 00000282f53c4a40] Application provided invalid, non monotonically increasing dts to muxer in stream 0: 1383328800 >= 1383187680
# size=    1536KiB time=00:01:38.39 bitrate= 127.9kbits/s speed=6.15x
# size=    1536KiB time=00:01:38.62 bitrate= 127.6kbits/s speed=5.98x
# size=    1536KiB time=00:01:39.23 bitrate= 126.8kbits/s speed=5.83x
# size=    1536KiB time=00:01:39.23 bitrate= 126.8kbits/s speed=5.66x
# [out#0/mp3 @ 00000282f53eedc0] video:0KiB audio:1571KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 0.026601%
# size=    1572KiB time=00:01:39.67 bitrate= 129.2kbits/s speed=5.63x
#
# Exported combined audio for SPEAKER_04 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_SPEAKER_07_13_output_combined_output_combined.mp3
# Running audio split command: ffmpeg -y -hwaccel cuda -f concat -safe 0 -i 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_segments.txt' -c copy 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_SPEAKER_07_13_output_combined_output_combined.mp3'
#
# ffmpeg version 7.0-full_build-www.gyan.dev Copyright (c) 2000-2024 the FFmpeg developers
#   built with gcc 13.2.0 (Rev5, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-bzlib --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libaribb24 --enable-libaribcaption --enable-libdav1d --enable-libdavs2 --enable-libuavs3d --enable-libxevd --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxavs2 --enable-libxeve --enable-libxvid --enable-libaom --enable-libjxl --enable-libopenjpeg --enable-libvpx --enable-mediafoundation --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libharfbuzz --enable-liblensfun --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-dxva2 --enable-d3d11va --enable-d3d12va --enable-ffnvcodec --enable-libvpl --enable-nvdec --enable-nvenc --enable-vaapi --enable-libshaderc --enable-vulkan --enable-libplacebo --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libcodec2 --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      59.  8.100 / 59.  8.100
#   libavcodec     61.  3.100 / 61.  3.100
#   libavformat    61.  1.100 / 61.  1.100
#   libavdevice    61.  1.100 / 61.  1.100
#   libavfilter    10.  1.100 / 10.  1.100
#   libswscale      8.  1.100 /  8.  1.100
#   libswresample   5.  1.100 /  5.  1.100
#   libpostproc    58.  1.100 / 58.  1.100
# Input #0, concat, from 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_segments.txt':
#   Duration: 00:00:01.72, start: -0.004000, bitrate: 1 kb/s
#   Stream #0:0: Audio: mp3 (mp3float), 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
# Output #0, mp3, to 'z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_SPEAKER_07_13_output_combined_output_combined.mp3':
#   Metadata:
#     TSSE            : Lavf61.1.100
#   Stream #0:0: Audio: mp3, 48000 Hz, stereo, fltp, 128 kb/s
#       Metadata:
#         encoder         : Lavf
# Press [q] to stop, [?] for help
# size=      14KiB time=00:00:00.90 bitrate= 129.0kbits/s speed=1.73x
# [out#0/mp3 @ 000001df946a8540] video:0KiB audio:27KiB subtitle:0KiB other streams:0KiB global headers:0KiB muxing overhead: 1.526826%
# size=      28KiB time=00:00:01.73 bitrate= 131.4kbits/s speed=1.77x
#
# Exported combined audio for SPEAKER_03 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_SPEAKER_07_13_output_combined_output_combined.mp3
# Saved words for speaker SPEAKER_07 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_07_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_08 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_08_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_00 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_00_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_11 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_11_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_10 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_10_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_06 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_06_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_02 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_02_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_09 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_09_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_05 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_05_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_01 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_01_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_04 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_04_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker unknown to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\unknown_SPEAKER_07_13_output_combined_output_words.txt
# Saved words for speaker SPEAKER_03 to z:\AI\Whisper\SPEAKER_07_13_output_combined_output\SPEAKER_03_SPEAKER_07_13_output_combined_output_words.txt
